# %%
import pandas as pd
import plotly.express as px
from datetime import datetime
import pytz

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
ist = pytz.timezone('Asia/Kolkata')
current_time = datetime.now(ist).time()
start_time = datetime.strptime('17:00:00', '%H:%M:%S').time()
end_time   = datetime.strptime('19:00:00', '%H:%M:%S').time()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data = df.copy()
data['Reviews'] = pd.to_numeric(data['Reviews'], errors='coerce')
df['Size'] = df['Size'].str.replace('M', '', regex=False).str.replace('k', '', regex=False)
data['Installs'] =data['Installs'].str.replace('+', '', regex=False).str.replace(',', '', regex=False)
data['Installs'] = pd.to_numeric(data['Installs'], errors='coerce')

# %%
data =data[
        (data['Rating'] > 3.5) &
        (data['Category'].isin(['GAME', 'BEAUTY', 'BUSINESS', 'COMICS', 'COMMUNICATION',
                              'DATING', 'ENTERTAINMENT', 'SOCIAL', 'EVENTS'])) &
        (data['Reviews'] > 500) &
        (data['Installs'] > 50000) &
        (data['App'].str.contains("S", case=False, na=False)) 
    ].copy()

# %%
translations = {
        "Beauty": "सौंदर्य",          # Hindi
        "Business": "வணிகம்",        # Tamil
        "Dating": "Verabredung"      # German
    }

# %%
 data['Category'] = data['Category'].replace(translations)

# %%
if start_time <= current_time <= end_time:
    fig = px.scatter(
        filtered,
        x="Size_MB",
        y="Rating",
        size="Installs",
        color="Category",
        hover_data=["App", "Reviews"],
        title="App Size vs Rating (Bubble size = Installs)"
    )

    # Highlight "Game" categorys in Pink in structure
    fig.for_each_trace(
        lambda trace: trace.update(marker=dict(color="pink"))
        if trace.name == "Game" else ()
    )

    fig.update_layout(
        plot_bgcolor="white",
        paper_bgcolor="white",
        font_color="black",
        title_font=dict(size=16),
        xaxis=dict(title_font=dict(size=12)),
        yaxis=dict(title_font=dict(size=12)),
        margin=dict(l=10, r=10, t=30, b=10)
    )
    fig.show()
else:
    print("This chart (App Size vs Rating Bubble Chart) is only visible between 5 PM and 7 PM IST.")
# Out:
# This chart (App Size vs Rating Bubble Chart) is only visible between 5 PM and 7 PM IST.
